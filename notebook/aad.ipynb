# %% [markdown]
# ## PV01
#
# The *PV01* for a plain vanilla swap can be calculated as
#
# $$PV01 = 0.01\% \sum_{i=\alpha +1}^{\beta} \tau_i P(0, T_i)$$

# %%
from finmarkets import generate_dates, SwapSide

class InterestRateSwap:
    def __init__(self, nominal, start_date, maturity, fixed_rate, frequency_fix="12m", side=SwapSide.Receiver):
        self.N = nominal
        self.K = fixed_rate
        self.dates = generate_dates(start_date, maturity, frequency_fix)
        self.side = side

    def npv(self, dc):
      A = self.annuity(dc)
      return self.N*(self.K*A - dc.df(self.dates[0]) + dc.df(self.dates[-1]))

    def swap_rate_single_curve(self, dc):
        den = 0
        num = dc.df(self.dates[0]) - dc.df(self.dates[-1])
        for i in range(1, len(self.dates)):
            tau = (self.dates[i]-self.dates[i-1]).days/360
            den += dc.df(self.dates[i])*tau
        return num/den

    def annuity(self, dc):
        a = 0
        for i in range(1, len(self.dates)):
            tau = (self.dates[i]-self.dates[i-1]).days/360
            a += tau*dc.df(self.dates[i])
        return a

    def pv01(self, dc):
        return 0.0001*self.annuity(dc)

# %%
from datetime import date
from dateutil.relativedelta import relativedelta
from finmarkets import DiscountCurve #, InterestRateSwap

n = 6
today = date.today()
dates = [today+relativedelta(years=i) for i in range(n)]
dfs = [1/(1+0.05)**i for i in range(n)]
dc = DiscountCurve(dates, dfs)

irs = InterestRateSwap(1, today, "5y", 0.055, "3m")

print ("IRS PV01: {:.5f}".format(irs.pv01(dc)))
# Out:
# IRS PV01: 0.00045

# %% [markdown]
# ## DV01
#
# One way to compute DV01, is by manually shift the interest rate curve, compute the contract price twice and check the variation.
# This is essentially the application of the derivative estimate performed using **finite differences**.

# %%
import numpy as np

from datetime import date
from dateutil.relativedelta import relativedelta
from finmarkets import DiscountCurve

n = 6
today = date.today()
dates = [today+relativedelta(years=i) for i in range(n)]

dr = 0.0001
rates_up = np.array([0.05]*n) + dr
rates_down = np.array([0.05]*n) - dr
dfs_up = [1/(1+rates_up[i])**i for i in range(n)]
dfs_down = [1/(1+rates_down[i])**i for i in range(n)]
dc_up = DiscountCurve(dates, dfs_up)
dc_down = DiscountCurve(dates, dfs_down)

irs = InterestRateSwap(1, today, "5y", 0.055, "3m")
dv01 = (irs.npv(dc_down) - irs.npv(dc_up))/2
print (f"IRS DV01: {dv01:.5f}")
# Out:
# IRS DV01: 0.00043

# %% [markdown]
# \begin{equation}
# \textbf{DV01} = \underbrace{-\sum_{j}\tau_jP_j}_{\text{PV01}}+\underbrace{\sum_{j}\left(K\sum_{i=\alpha+1}^\beta\tau_i\frac{\partial P_i}{\partial r_j} - \sum_{k=\alpha+1}^\beta L_k\tau_k\frac{\partial P_k}{\partial r_j}\right)}_{\text{additional terms}}
# \end{equation}

# %% [markdown]
# ## Algorithmic Differientation
#
# #### Exercise 6.1
# Consider the following function
# \begin{equation}
# \begin{cases}
# \text{Function: } f(x_0, x_1) = 2x_0^2 + 3x_1\\
# \text{Solution: } \frac{df}{dx_0} = 4x_0, \text{ and } \frac{df}{dx_1}=3
# \end{cases}
# \end{equation}
#
# Compute the AD both using tangent and adjoint technique, when $x_0=2$ and $x_1=3$,
# \begin{equation}
# \frac{df}{dx_0} = 8, \text{ and } \frac{df}{dx_1}=3
# \end{equation}

# %%
import torch

def f(x):
    return 2*x[0]**2 + 3*x[1]

def df_tangent(x):
    return 4*x[0], 3

def df_adjoint(x_input):
    x = torch.tensor(x_input, dtype=torch.float32, requires_grad=True)

    y = 2*x[0]**2 + 3*x[1]
    y.backward()
    return x.grad

x = (2.0, 3.0)

print(f"Function value f(x): {f(x)}")
print(f"Manual Gradient (Tangent): {df_tangent(x)}")
print(f"Auto-diff Gradient (Adjoint): {df_adjoint(x).tolist()}")
# Out:
# Function value f(x): 17.0
# Manual Gradient (Tangent): (8.0, 3)
# Auto-diff Gradient (Adjoint): [8.0, 3.0]

# %% [markdown]
# #### Example
#
# Consider a 5-years receiver Interest Rate Swap with a 1M notional, exchanging a fixed rate of 5\% with a flat 1\% LIBOR rate with annual payments.
# Compute DV01 with and without algorithmic differentiation. Compare the results.

# %%
from finmarkets import generate_dates, SwapSide
from finmarkets import GlobalConst

from itertools import pairwise

class InterestRateSwap:
    def __init__(self, nominal, start_date, maturity, fixed_rate, frequency_float, frequency_fix="1y", side=SwapSide.Receiver):
        self.nominal = nominal
        self.fixed_rate = fixed_rate
        self.fix_dates = generate_dates(start_date, maturity, frequency_fix)
        self.float_dates = generate_dates(start_date, maturity, frequency_float)
        self.side = side

    def dv01_tangent_mode(self, dc, dr=0.0001):
        temp = 0.0
        for d0, d1 in pairwise(self.fix_dates):
            tau = (d1-d0).days / 360
            t = (d1 - GlobalConst.OBSERVATION_DATE).days / 365
            temp += -t * tau * dc.df(d1)
        dfixed_pv = self.nominal * self.fixed_rate * dr * temp

        temp = 0.0
        for d0, d1 in pairwise(self.float_dates):
            tau = (d1-d0).days / 365
            t_start = (d0 - self.float_dates[0]).days / 365
            t_end = (d1 - self.float_dates[0]).days / 365

            P_start = dc.df(d0)
            P_end = dc.df(d1)
            F = (P_start/P_end - 1)/tau

            dF_dr = (t_end - t_start) * (P_start / (tau * P_end))
            term = (dF_dr * P_end) + (F * (-t_end * P_end)) / tau
            temp += term

        dfloat_pv = self.nominal * dr * temp
        print (dfixed_pv, dfloat_pv)
        return self.side*(dfixed_pv - dfloat_pv)
    
    def npv(self, dc):
        temp = sum([dc.df(d1) * (d1-d0).days / 365 for d0, d1 in pairwise(self.fix_dates)])
        fixed_pv = self.nominal * self.fixed_rate * temp

        temp = 0.0
        for d0, d1 in pairwise(self.float_dates):
            tau = (d1-d0).days / 365
            P_start = dc.df(d0)
            P_end = dc.df(d1)
            F = (P_start/P_end - 1)/tau          
            temp += F * tau * dc.df(d1)
        float_pv = self.nominal * temp
        return self.side*(fixed_pv - float_pv)

# %%
import numpy as np

from finmarkets import TimeInterval, DiscountCurve#, FlatTermStructure

years = 5
dates = [GlobalConst.OBSERVATION_DATE + TimeInterval(f"{i}y") for i in range(years+1)]
rates = np.array([0.015]*(years+1))
dc = DiscountCurve(dates, np.exp(-rates*np.arange(0, years+1)))

fixed_rate = 0.05

swap = InterestRateSwap(1e06, GlobalConst.OBSERVATION_DATE, f"{years}y", fixed_rate, "1y", "3m", SwapSide.Receiver)
print (swap.dv01_tangent_mode(dc))
# Out:
# -63.29308895429578 463.87205466889014
# -527.1651436231859

# %%
import torch

class torch_DiscountCurve:
    def __init__(self, pillar_dates, rates):
        self.pillar_dates = pillar_dates
        self.t_pillars = torch.tensor([(p - GlobalConst.OBSERVATION_DATE).days / 365 for p in pillar_dates], dtype=torch.float32)
        # if isinstance(rates, torch.Tensor):
        self.rates = rates
        # else:
        #     self.rates = torch.tensor(rates, dtype=torch.float64, requires_grad=True)
        self.dfs = torch.exp(-self.rates * self.t_pillars)
        if 0 not in self.t_pillars:
            self.t_pillars =  torch.cat([torch.tensor([0.0], dtype=torch.float32), self.t_pillars])
            self.dfs = torch.cat([torch.tensor([1.0], dtype=torch.float32, requires_grad=True), self.dfs])
        self.log_dfs = torch.log(self.dfs)

    def df(self, adate):
        d = torch.tensor((adate - GlobalConst.OBSERVATION_DATE).days / 365)
        idx = torch.searchsorted(self.t_pillars, d)
        d_prev, d_next = self.t_pillars[idx-1], self.t_pillars[idx]
        log_df_prev, log_df_next = self.log_dfs[idx-1], self.log_dfs[idx]

        alpha = (d - d_prev) / (d_next - d_prev)
        interp_log_df = log_df_prev + alpha * (log_df_next - log_df_prev)

        return torch.exp(interp_log_df)

class torch_TermStructure:
    def __init__(self, pillars_dates, spot_rates):
        self.pillars_dates = pillars_dates
        self.t_pillars = torch.tensor([(p - GlobalConst.OBSERVATION_DATE).days / 365 for p in pillars_dates], dtype=torch.float32)

        # if not isinstance(spot_rates, torch.Tensor):
        #     self.rates = torch.tensor(spot_rates, dtype=torch.float32, requires_grad=True)
        # else:
        self.rates = spot_rates

    def interp_rate(self, adate):
        d = torch.tensor((adate - GlobalConst.OBSERVATION_DATE).days / 365.0, dtype=torch.float32)

        if d < self.t_pillars[0] or d > self.t_pillars[-1]:
            raise ValueError(f"Cannot extrapolate rates (date: {adate}).")

        idx = torch.searchsorted(self.t_pillars, d)

        if d == self.t_pillars[0]:
            return d, self.rates[0]

        d_prev = self.t_pillars[idx-1]
        d_next = self.t_pillars[idx]
        r_prev = self.rates[idx-1]
        r_next = self.rates[idx]

        alpha = (d - d_prev) / (d_next - d_prev)
        r_interp = r_prev + alpha * (r_next - r_prev)

        return d, r_interp

    def forward_rate(self, d1, d2):
        t1, r1 = self.interp_rate(d1)
        t2, r2 = self.interp_rate(d2)

        return (r2 * t2 - r1 * t1) / (t2 - t1)
    
from itertools import pairwise

from finmarkets import generate_dates, SwapSide, GlobalConst

class torch_InterestRateSwap:
    def __init__(self, nominal, start_date, maturity, fixed_rate, frequency_float, frequency_fix="1y", side=SwapSide.Receiver):
        self.nominal = torch.tensor(float(nominal))
        self.fixed_rate = torch.tensor(float(fixed_rate))
        self.fix_dates = generate_dates(start_date, maturity, frequency_fix)
        self.float_dates = generate_dates(start_date, maturity, frequency_float)
        self.side = torch.tensor(float(side))

    def annuity(self, dc):
        a = torch.tensor(0.0, dtype=torch.float64)

        for d0, d1 in pairwise(self.fix_dates):
            tau = (d1-d0).days / 365.0
            a = a + tau * dc.df(d1)
        return a

    def swap_rate(self, dc):
        num = 0.0
        for d0, d1 in pairwise(self.float_dates):        
            tau = (d1-d0).days / 365.0
            F = (dc.df(d0)/dc.df(d1) - 1)/tau            
            D = dc.df(d1)
            num = num + (F * tau * D)
        return num / self.annuity(dc)

    def npv_fixed(self, dc):
        return self.nominal * self.fixed_rate * sum([dc.df(d1)*(d1-d0).days / 365 for d0, d1 in pairwise(self.fix_dates)])

    def npv_float(self, dc):
        npv = 0.0
        for d0, d1 in pairwise(self.float_dates):
          tau = (d1-d0).days / 365
          F = (dc.df(d0)/dc.df(d1) - 1)/tau
          D = dc.df(d1)
          npv += tau * F * D
        return self.nominal * npv

    def npv(self, dc):
        return self.side * (self.npv_fixed(dc) - self.npv_float(dc))

    def npv2(self, dc):
        S = self.swap_rate(dc)
        A = self.annuity(dc)
        return self.side * self.nominal * (self.fixed_rate - S) * A

# %%
import torch

from finmarkets import TimeInterval

dates = [GlobalConst.OBSERVATION_DATE + TimeInterval(f"{i}y") for i in range(7)]
rates = torch.tensor([0.015,0.015,0.015,0.015,0.015,0.015,0.015], dtype=torch.float32, requires_grad=True)
dc = torch_DiscountCurve(dates, rates)
fixed_rate = 0.05

torch_swap = torch_InterestRateSwap(1_000_000, GlobalConst.OBSERVATION_DATE, "5y", fixed_rate, "1y", "3m")

fixed_val = torch_swap.npv_fixed(dc)
fixed_val.backward(retain_graph=True)
delta_fixed = rates.grad.clone()*0.0001
rates.grad.zero_()

float_val = torch_swap.npv_float(dc)
float_val.backward(retain_graph=True)
delta_float = rates.grad.clone()*0.0001

print("Fixed Leg Delta:", delta_fixed.sum())
print("Floating Leg Delta:", delta_float)

rates.grad.zero_()
current_npv = torch_swap.npv(dc)
current_npv.backward(retain_graph=True)
print (rates.grad.clone().sum()*0.0001)
# Out:
# Fixed Leg Delta: tensor(-62.4237)
# Floating Leg Delta: tensor([ 0.0000e+00, -6.2500e-06,  1.2517e-05,  0.0000e+00, -2.5017e-05,
#          4.6411e+02,  0.0000e+00])
# tensor(-526.5306)

# %% [markdown]
# # Greeks and AAD
#
# ## Linear vs Non-Linear
#
# In a linear world (FRAs, Swaps), your exposure is constant regardless of where the market moves.
#
# In a non-linear world (Caps, Floors), your exposure changes dynamically as rates shift.
#
# In a linear derivative if interest rates go up by 1 bp, the value changes by a fixed amount (the PV01). It has $\Delta$ but zero $\Gamma$.
#
# In a non-linear derivative, the sensitivity to rates depends on whether the option is In-The-Money (ITM) or Out-Of-The-Money (OTM). It has $\Delta$ AND $\Gamma$.
#
# Hedging an FRA is a "set it and forget it" task.
#
# To hedge the Cap, you must constantly buy or sell more underlying (Swaps/FRAs) as rates move (Dynamic Hedging).
#
# If rates jump from 3% to 5% overnight, your FRA risk didn't change, but your Cap risk doubled. This "exploding risk" is what $\Gamma$ measures.

# %%
import torch, numpy as np
import matplotlib.pyplot as plt

notional = 10_000_000
strike = torch.tensor(0.05)
vol = torch.tensor(0.20, requires_grad=True)
ttm = torch.tensor(1.0, requires_grad=True)
rates = torch.linspace(0.01, 0.1, 200)

fra_delta = np.full_like(rates, notional * 0.01)

def price_caplet(F, K, sigma, T):
    d1 = (torch.log(F / K) + 0.5 * sigma**2 * T) / (sigma * torch.sqrt(T))
    d2 = d1 - sigma * torch.sqrt(T)
    phi = lambda x: 0.5 * (1 + torch.erf(x / torch.sqrt(torch.tensor(2.0))))
    #discount = torch.exp(-r * T) # WE CAN IGNORE THE DISCOUNT FOR WHAT WE ARE DOING
    price = (F * phi(d1) - K * phi(d2))
    return price * notional

deltas, vegas, thetas = np.zeros(len(rates)), np.zeros(len(rates)), np.zeros(len(rates))

for i, r in enumerate(rates):
  f_rate = r.detach().clone().requires_grad_(True)
    
  price = price_caplet(f_rate, strike, vol, ttm)
  price.backward()
    
  deltas[i] = f_rate.grad.item()*0.01
  
plt.figure(figsize=(12, 6))
plt.plot(rates.numpy() * 100, fra_delta/1000, label='FRA Delta (Linear)', color='navy', lw=3)
plt.plot(rates.numpy() * 100, deltas/1000, label='Cap Delta (Non-Linear)', color='crimson', lw=3, linestyle='--')

plt.axvline(strike*100, color='gray', linestyle=':', label='Strike (5%)')
plt.title("Delta Risk Profile: FRA (Linear) vs. Cap (Non-Linear)")
plt.xlabel("Forward Interest Rate (%)")
plt.ylabel("Delta Exposure ($ Thousands per 1% move)")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Adding Volatility
#
# When we add the volatility to the mix, the difference between linear and non-linear portfolios becomes even more dramatic.
#
# While a linear portfolio (FRAs/Swaps) has a $\Delta$ that is "blind" to volatility, a non-linear portfolio (Caps/Floors) has a $\Delta$ profile that "warps" whenever market uncertainty changes. This interaction is known as *Vanna* (the change in $\Delta$ with respect to Volatility $=\frac{\partial^2 V}{\partial r \partial \sigma}$).
#
# In the plot below, you can see how the same Cap reacts to interest rates under different volatility regimes:
#
# * Low Volatility: the $\Delta$ is "binary." It stays at zero until the rate hits the strike, then it snaps upward almost instantly. This is dangerous because it creates "Gap Risk"—one small move in rates can suddenly turn a zero-risk position into a massive exposure.
# * High Volatility: the S-curve flattens. Because there is a higher "probability" of the rate ending up in-the-money, the Cap starts behaving like it has $\Delta$ risk even when rates are far below the strike (Out-of-the-Money).
#
# FRA remains a perfectly flat horizontal line (since $V$ doesn't depend on $\sigma$). Its risk is 100% predictable regardless of volatility.
#
# #### The Portfolio Manager's Dilemma
#
# This visualization reveals why managing a Cap portfolio is significantly harder than a Swap portfolio.
#
# * If you are "$\Delta$-Hedging" a Cap and volatility spikes, your $\Delta$ profile flattens. You may suddenly find yourself "over-hedged" or "under-hedged" even if interest rates haven't moved a single basis point.
# * "Sticky Delta" vs. "Sticky Strike": traders must decide if they hedge based on the current $\Delta$ (which moves with $\sigma$) or a fixed assumption.

# %%
volatilities = [0.1, 0.2, 0.4, 0.8]

plt.figure(figsize=(10, 6))

for sigma in volatilities:
    deltas = np.zeros(len(rates))
    for i, r in enumerate(rates):
      f_rate = r.detach().clone().requires_grad_(True)     
      price = price_caplet(f_rate, strike, sigma, ttm)
      price.backward()
      deltas[i] = f_rate.grad.item()*0.01
       
    plt.plot(rates.numpy() * 100, deltas/1000, label=r'Caplet Delta ($\sigma$='+f'{sigma*100:.0f}%)')

plt.axvline(strike.item() * 100, color='gray', linestyle='--', alpha=0.5, label='Strike (5%)')
plt.xlabel('Forward Rate (%)')
plt.ylabel(r'Delta ($\partial V / \partial F$)')
plt.legend(loc='lower right', frameon=True)
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Vega Sensitivity
#
# $\Delta$ is highest when the option is deep in-the-money, Vega instead is highest when the rate is ATM. This is because then the rate is *exactly* at the strike, the uncertainty of whether the option will finish in or out the moeny is at its peak.

# %%
vols = [0.10, 0.25, 0.40]
vega = {v: np.zeros(len(rates)) for v in vols}

for i, r in enumerate(rates):
    for v in vols:
      f_rate = r.detach().clone().requires_grad_(True)
      sigma = torch.tensor(v, requires_grad=True)
        
      price = price_caplet(f_rate, strike, sigma, ttm)
      price.backward()
      vega[v][i] = sigma.grad.item() * 0.01

plt.figure(figsize=(10, 6))
colors = ['forestgreen', 'crimson', 'darkorange']

for v, col in zip(vols, colors):
    plt.plot(rates.numpy()*100, vega[v], label=f'Cap Vega (Vol={v*100:.0f}%)', color=col, lw=2.5)

plt.plot(rates.numpy()*100, torch.zeros_like(rates), label='FRA Vega', color='black', lw=1.5, linestyle='--')
plt.axvline(strike.item()*100, color='gray', linestyle=':', label='Strike (5%)')
plt.ylabel("USD Change")
plt.xlabel("Interest Rate (%)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Theta Sensitivity
#
# $\Theta$ refers to the loss of value over time.
#
# **Note:** the minus sign in the Theta (Θ) calculation below; this is required because of a directional conflict between how we measure calendar time versus time-to-maturity.
# In our pricing function `price_caplet`, the variable `T` represents Time-to-Maturity. As the calendar time ($t$) moves forward, the time-to-maturity moves backward (decreases).
# Mathematically: $T=\text{Expiry}-t$ therefore, the change in time is inverse: $dt=-dT$.

# %%
theta = np.zeros(len(rates))

for i, r in enumerate(rates):
    f_rate = r.detach().clone().requires_grad_(True)
    sigma = torch.tensor(0.25, requires_grad=True)
    T = torch.tensor(1.0, requires_grad=True)
              
    price = price_caplet(f_rate, strike, sigma, T)
    price.backward()
    theta[i] = -T.grad.item()/365

plt.figure(figsize=(10, 6))
plt.plot(rates.numpy()*100, theta, label='Cap Theta (Vol=25%)', color='royalblue', lw=3)
plt.plot(rates.numpy()*100, torch.zeros_like(rates), label='FRA Theta', color='black', lw=1.5, linestyle='--')
plt.axvline(strike.item()*100, color='gray', linestyle=':', label='Strike (5%)')
plt.ylabel("USD Decay per Day")
plt.xlabel("Interest Rate (%)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# For a risk manager, though, the more interesting effect is how time changes $\Delta$ profile ("Pinning Risk").
#
# Long time to expiry you have $\Delta$ exposure even if the rate is 1\% away from the strike.
#
# As you get closer to expiry, the curve becomes a cliff. If the rate is 3.99\% and the strike is 4.00\%, you have zero $\Delta$. If the rate moves to 4.01\%, you suddenly have 100\% $\Delta$.
#
# This is where traders get "pinned." You have to hedge and re-hedge frantically as the rate dances around the strike in the final hours, because your $\Delta$ is jumping between 0 and 1 (infinite $\Gamma$).

# %%
time_periods = [1.0, 0.25, 0.083, 0.019] 
labels = ['1 Year', '3 Months', '1 Month', '1 Week']

plt.figure(figsize=(10, 6))

for T_val, label in zip(time_periods, labels):
    deltas = np.zeros(len(rates))
    T = torch.tensor(T_val)
    
    for i, r in enumerate(rates):
      f_rate = r.detach().clone().requires_grad_(True)                
      price = price_caplet(f_rate, strike, sigma, T)
      price.backward()
      deltas[i] = f_rate.grad.item()*0.01

    plt.plot(rates.numpy() * 100, deltas, label=f'Time to Expiry: {label}', lw=2)

plt.axvline(strike.item() * 100, color='black', linestyle='--', alpha=0.5, label='Strike (5%)')
plt.xlabel('Forward Rate (%)', fontsize=12)
plt.ylabel(r'Delta ($\partial V / \partial F$)', fontsize=12)
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()
